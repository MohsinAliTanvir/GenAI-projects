# %% [markdown]
# # PA1.1 Text Generation using Shannon Visualization Method
#
# ### Introduction
#
# In this notebook, you will be generating text using the Shannon Visualization method.
#
# An n-gram is a contiguous sequence of n words. For example "Machine" is a unigram, "Machine Learning" is a bigram and "Machine Learning PA1" is a trigram. In language modeling, n-gram models are probabilistic models of text that use word dependencies and context to predict the likelihood of occurence of an n-gram, i.e. predicting the nth word in an n-gram based on the previous n-1 words. One use of the predictions made by such a model is text generation. In this part, you will be generating text using the Shannon Visualization Method.
#
# For additional details of the working of n-gram models and shannon visualization method, you can also consult [Chapter 3](https://web.stanford.edu/~jurafsky/slp3/3.pdf) of the SLP3 book as reference.
#
# ### Instructions
#
# - Follow along with the notebook, filling out the necessary code where instructed.
#
# - <span style="color: red;">Read the Submission Instructions, Plagiarism Policy, and Late Days Policy in the attached PDF.</span>
#
# - <span style="color: red;">Make sure to run all cells for credit.</span>
#
# - <span style="color: red;">Do not remove any pre-written code.</span>
#
# - <span style="color: red;">You must attempt all parts.</span>
#
# For this notebook, in addition to standard libraries i.e. `numpy`, `pandas`, `regex`, `matplotlib` and `scipy`, you **can** use [UrduHack](https://github.com/urduhack/urduhack) for tokenization, and [NLTK](https://www.nltk.org/) for training your n-grams. However, no other machine learning toolkits or libraries are allowed.

# %%
#Installing the dependencies
# %pip install matplotlib numpy pandas regex matplotlib scipy urduhack nltk

# import all required libraries here
import numpy as np
import pandas as pd
import regex as re
import matplotlib.pyplot as plt
import scipy
import nltk
import urduhack
urduhack.download()
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (3.8.2)
# Requirement already satisfied: numpy in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (1.26.3)
# Requirement already satisfied: pandas in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (2.2.0)
# Requirement already satisfied: regex in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (2023.12.25)
# Requirement already satisfied: scipy in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (1.12.0)
# Requirement already satisfied: urduhack in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (1.1.1)
# Requirement already satisfied: nltk in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (3.8.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from matplotlib) (4.47.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: cycler>=0.10 in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: packaging>=20.0 in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from matplotlib) (6.1.1)
# Requirement already satisfied: pillow>=8 in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from pandas) (2023.4)
# Requirement already satisfied: tf2crf in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from urduhack) (0.1.33)
# Requirement already satisfied: Click~=7.1 in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from urduhack) (7.1.2)
# Requirement already satisfied: tensorflow-datasets~=3.1 in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from urduhack) (3.2.1)
# Requirement already satisfied: joblib in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from nltk) (1.3.2)
# Requirement already satisfied: tqdm in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from nltk) (4.66.1)
# Requirement already satisfied: zipp>=3.1.0 in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.17.0)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)
# Requirement already satisfied: attrs>=18.1.0 in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from tensorflow-datasets~=3.1->urduhack) (23.2.0)
# Requirement already satisfied: tensorflow-metadata in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from tensorflow-datasets~=3.1->urduhack) (1.14.0)
# Requirement already satisfied: requests>=2.19.0 in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from tensorflow-datasets~=3.1->urduhack) (2.31.0)
# Requirement already satisfied: promise in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from tensorflow-datasets~=3.1->urduhack) (2.3)
# Requirement already satisfied: termcolor in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from tensorflow-datasets~=3.1->urduhack) (2.4.0)
# Requirement already satisfied: future in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow-datasets~=3.1->urduhack) (0.18.2)
# Requirement already satisfied: absl-py in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from tensorflow-datasets~=3.1->urduhack) (1.4.0)
# Requirement already satisfied: protobuf>=3.6.1 in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from tensorflow-datasets~=3.1->urduhack) (3.20.3)
# Requirement already satisfied: wrapt in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from tensorflow-datasets~=3.1->urduhack) (1.14.1)
# Requirement already satisfied: dill in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from tensorflow-datasets~=3.1->urduhack) (0.3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from requests>=2.19.0->tensorflow-datasets~=3.1->urduhack) (2.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from requests>=2.19.0->tensorflow-datasets~=3.1->urduhack) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from requests>=2.19.0->tensorflow-datasets~=3.1->urduhack) (2024.2.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from requests>=2.19.0->tensorflow-datasets~=3.1->urduhack) (3.6)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from tensorflow-metadata->tensorflow-datasets~=3.1->urduhack) (1.62.0)
# Requirement already satisfied: tensorflow-addons>=0.8.2 in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from tf2crf->urduhack) (0.23.0)
# Requirement already satisfied: tensorflow>=2.1.0 in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from tf2crf->urduhack) (2.15.0)
# Requirement already satisfied: tensorflow-macos==2.15.0 in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from tensorflow>=2.1.0->tf2crf->urduhack) (2.15.0)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0->tensorflow>=2.1.0->tf2crf->urduhack) (0.5.4)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0->tensorflow>=2.1.0->tf2crf->urduhack) (2.15.1)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0->tensorflow>=2.1.0->tf2crf->urduhack) (2.15.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0->tensorflow>=2.1.0->tf2crf->urduhack) (1.6.3)
# Requirement already satisfied: libclang>=13.0.0 in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0->tensorflow>=2.1.0->tf2crf->urduhack) (16.0.6)
# Requirement already satisfied: setuptools in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow-macos==2.15.0->tensorflow>=2.1.0->tf2crf->urduhack) (58.0.4)
# Requirement already satisfied: h5py>=2.9.0 in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0->tensorflow>=2.1.0->tf2crf->urduhack) (3.10.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0->tensorflow>=2.1.0->tf2crf->urduhack) (1.60.1)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0->tensorflow>=2.1.0->tf2crf->urduhack) (2.15.0)
# Requirement already satisfied: flatbuffers>=23.5.26 in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0->tensorflow>=2.1.0->tf2crf->urduhack) (23.5.26)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0->tensorflow>=2.1.0->tf2crf->urduhack) (4.9.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0->tensorflow>=2.1.0->tf2crf->urduhack) (3.3.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0->tensorflow>=2.1.0->tf2crf->urduhack) (0.2.0)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0->tensorflow>=2.1.0->tf2crf->urduhack) (0.2.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0->tensorflow>=2.1.0->tf2crf->urduhack) (0.34.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow-macos==2.15.0->tensorflow>=2.1.0->tf2crf->urduhack) (0.37.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow>=2.1.0->tf2crf->urduhack) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow>=2.1.0->tf2crf->urduhack) (1.2.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow>=2.1.0->tf2crf->urduhack) (3.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow>=2.1.0->tf2crf->urduhack) (3.5.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow>=2.1.0->tf2crf->urduhack) (0.7.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow>=2.1.0->tf2crf->urduhack) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow>=2.1.0->tf2crf->urduhack) (0.3.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow>=2.1.0->tf2crf->urduhack) (5.3.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow>=2.1.0->tf2crf->urduhack) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from markdown>=2.6.8->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow>=2.1.0->tf2crf->urduhack) (7.0.1)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow>=2.1.0->tf2crf->urduhack) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow>=2.1.0->tf2crf->urduhack) (3.2.2)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from tensorflow-addons>=0.8.2->tf2crf->urduhack) (2.13.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow>=2.1.0->tf2crf->urduhack) (2.1.5)
# WARNING: You are using pip version 21.2.4; however, version 23.3.2 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/mohsintanveer/Library/Python/3.9/lib/python/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %% [markdown]
# ### Dataset
#
# You will be using the Urdu short stories by Patras Bukhari given in the folder `Urdu Short Stories` in the attached zip file for the purposes of this part of the assignment. This contains 6 stories of varying lengths which will serve as inputs for your n-gram model.
#
# You're required to implement an n-gram model that uses the given stories to generate Urdu text that mimics the input stories.

# %% [markdown]
# ## Loading and Preprocessing the Dataset
#
# Read in the short story files given and tokenize the text to be preprocessed.

# %%
# code here
# import nltk
from urduhack.tokenization import word_tokenizer
from urduhack import normalize
import os
urdu_stories=[]
tokenized_text=[]

for f in os.listdir('./DataP1'):
    story_location="./DataP1/"+ str(f)
    with open(story_location, 'r', encoding='utf-8') as file:
        story = file.read()
        urdu_stories.append(story)

# Adding the start and stop words for sentence generation in future (using bigrams) + Also removing \n tokens
# urdu_stories = [story.replace('۔', "<s>" +" "+ "</s>") for story in urdu_stories]
urdu_stories = [story.replace('\n', " ") for story in urdu_stories]

# Break each Urdu story into chunks of max length 256 because the urduhack model cannot take a length more than 256
chunked_urdu_stories = []

for story in urdu_stories:
    chunks = [story[i:i + 256] for i in range(0, len(story), 256)]
    chunked_urdu_stories.append(chunks)
print("chunked")
print(len(chunked_urdu_stories))

for i in range(6):
    #This is a preprocessing step to normalise the urdu sentences before creating tokens
    normalized_text = normalize(str(chunked_urdu_stories[i]))
    tokens=word_tokenizer(normalized_text)
    tokenized_text.append(tokens)

print(tokenized_text)
# Out:
# chunked
# 6
# 232/232 [==============================] - 56s 233ms/step
# 691/691 [==============================] - 167s 241ms/step
# 404/404 [==============================] - 98s 243ms/step
# 391/391 [==============================] - 95s 243ms/step
# 261/261 [==============================] - 63s 242ms/step
# 334/334 [==============================] - 77s 231ms/step
# [['میبل', 'لڑکیوں', 'کے', 'کالج', 'میں', 'تھی۔', 'لیکن', 'ہم', 'دونوں', 'کیمبرج', 'یونیورسٹی', 'میں', 'ایک', 'ہی', 'مضمون', 'پڑھتے', 'تھے،اس', 'لیے', 'اکثرلکچروں', 'میں', 'ملاقات', 'ہو', 'جاتی', 'تھی۔اس', 'کے', 'علاوہ', 'ہم', 'دوست', 'بھی', 'تھے۔', 'کئی', 'دلچسپیوں', 'میں', 'ایک', 'دوسرے', 'کے', 'شریک', 'ہوتے', 'تھے۔', 'تصویروں', 'اور', 'موسیقی', 'کاشوق', 'اسے', 'بھی', 'تھا،', 'میں', 'بھی', 'ہمہدانی', 'کادعویدار۔', 'اکثرگیلریوں', 'یاکانسرٹوں', 'میں', 'اکھٹے', 'جایاکرتے', 'تھ'], ['ہم', 'نے', 'کالج', 'میں', 'تعلیم', 'تو', 'ضرور', 'پائی', 'اور', 'رفتہ', 'رفتہ', 'بی،', 'اے', 'بھی', 'پاس', 'کر', 'لی', 'ا،', 'لیکن', 'اس', 'نصف', 'صدی', 'کے', 'دوران', 'جو', 'کالج', 'میں', 'گزارنی', 'پڑی،ہاسٹل', 'میں', 'داخل', 'ہونے', 'کی', 'اجازت', 'ہمیں', 'صرف', 'ایک', 'ہی', 'دفعہ', 'ملی۔', 'خدا', 'کا', 'یہ', 'فضل', 'ہم', 'پر', 'کب', 'اور', 'کس', 'طرح', 'ہوا،یہ', 'سوال', 'ایک', 'داستان', 'کا', 'محتاج', 'ہے۔', 'جب', 'ہم', 'نے', 'انٹرنس', 'پاس', 'کیا', 'تو', 'مقامی', 'اس', 'کول', 'کے', 'ہیڈ', 'ماسٹر', 'صاحب', 'خاص', 'طور', 'سے', 'مبارک', 'بعد', 'دینے', 'کے', 'لئ'], ['از', 'لاہور', 'اے', 'میرے', 'کراچی', 'کے', 'دوست', '!', 'چند', 'دن', 'ہوئے', 'میں', 'نے', 'اخبار', 'میں', 'یہ', 'خبر', 'پڑھی', 'کہ', 'کراچی', 'میں', 'فنون', 'لطیفہ', 'کی', 'ایک', 'انجمن', 'قائم', 'ہوئی', 'ہے', 'جو', 'وقتا', 'فوقتا', 'تصویروں', 'کی', 'نمائشوں', 'کا', 'اہتمام', 'کرے', 'گی۔', 'واضح', 'طور', 'پر', 'معلوم', 'نہ', 'ہو', 'سکا', 'کہ', 'اس', 'کے', 'کرتا', 'دھرتا', 'کو', 'ناہل', 'جنون', 'ہیں', 'لیکن', 'میں', 'جانتا', 'ہوں', 'کہ', 'آپ', 'کو', 'ای', 'سی', 'باتوں', 'کا', 'بے', 'انتہا', 'شوق', 'ہے۔', 'اور', 'مدت', 'سے', 'ہے۔', 'اور', 'آپ', 'ادب', 'اور', 'آرٹ', 'ک'], ['گیدڑ', 'کی', 'موت', 'آتیہےتوشہر', 'کی', 'طرف', 'دوڑتاہے', '۔', 'ہماری', 'جوشامت', 'آئی', 'توایک', 'دن', 'اپنے', 'پڑوسی', 'لالہ', 'کرپاش', 'نکرجی', 'برہم', 'چاری', 'سے', 'برسبیل', 'تذکرہ', 'کہہ', 'بیٹھے', 'کہ', 'لالہ', 'جی', 'امتحان', 'کے', 'دن', 'قریب', 'آتے', 'جاتے', 'ہیں،آپس', 'حرخیزہیں،ذراہمیںبھی', 'صبح', 'جگادیاکیجیئے', '۔وہ', 'حضرت', 'بھی', 'معلوم', 'ہوتاہے،لفظوںکے', 'بھوکے', 'بیٹھے', 'تھے۔', 'دوسرے', 'دن', 'اٹھتے', 'ہی', 'انھوںنے', 'ایشورکا', 'نام', 'لے', 'کرہما'], ['سینما', 'کا', 'عشق', 'عنوان', 'تو', 'عجب', 'ہوس', 'خیزہے،', 'لیکن', 'افسوس', 'کہ', 'اس', 'مضمون', 'سے', 'آپ', 'کی', 'تمام', 'توقعات', 'مجروح', 'ہوںگی۔', 'کیونکہ', 'مجھے', 'تو', 'اس', 'مضمون', 'میں', 'کچھ', 'دل', 'کے', 'داغ', 'دکھانے', 'مقصود', 'ہیں۔', 'اس', 'سے', 'آپ', 'یہ', 'نہ', 'سمجھئے', 'کہ', 'مجھے', 'فلموں', 'سے', 'دلچسپی', 'نہیں', '،یا', 'سینماکی', 'موسیقی', 'اورتاریکی', 'میں', 'جوارمان', 'انگیز', 'یہے', 'میں', 'اس', 'کا', 'قائل', 'نہیں۔', 'میں', 'تو', 'سینماکے', 'معاملے', 'میں', 'اوائل', 'عمر', 'ہی', 'سے', 'بزرگ'], ['تمہید', 'تمہید', 'کے', 'طور', 'پر', 'صرف', 'اتنا', 'عرض', 'کرنا', 'چاہتا', 'ہوں', 'کہ', 'لاہور', 'کو', 'دریافت', 'ہوئے', 'اب', 'بہت', 'عرصہ', 'گزر', 'چکا', 'ہے', 'اس', 'لیے', 'دلائل', 'وبراہین', 'سے', 'اس', 'کے', 'وجود', 'کو', 'ثابت', 'کرنے', 'کی', 'ضرورت', 'نہیں', '۔یہ', 'کہنے', 'کی', 'اب', 'ضرورت', 'نہیں', 'کہ', 'کرے', 'کو', 'دائیں', 'سے', 'بائیں', 'گھمائیے', '،حتی', 'کہ', 'ہندوستان', 'کا', 'ملک', 'آپ', 'کے', 'سامنے', 'آکر', 'ٹھہر', 'جائے', '۔', 'پھر', 'فلاں', 'طول', 'البلد', 'اور', 'فلاں', 'عرض', 'البلد', 'کے', 'مقام', 'انقطاع', 'پر', 'لاہ']]

# %% [markdown]
# Preprocess the tokenized data. Go through the data and use your own discretion to decide on what kind of pre-processing might be required.

# %%
# code here
from urduhack.preprocessing import remove_english_alphabets
#Converting the list into a flat list
tokenized_text_flat = [item for sublist in tokenized_text for item in sublist]

#Preprocessing the tokens
#1 Normalising using the normalise function of urdu hack already done
#2 Removing punctuation using regex
preprocessed_tokens = [re.sub(r'[^\w\s]', '', token) for token in tokenized_text_flat] 
#3 Removing empty tokens
preprocessed_tokens = [token for token in preprocessed_tokens if token] 

#4 filtering out non-urdu tokens
preprocessed_tokens = [remove_english_alphabets(token) for token in preprocessed_tokens]

print( 'preprocessed tokens:',preprocessed_tokens)
print(len(preprocessed_tokens))
# Out:
# preprocessed tokens: ['میبل', 'لڑکیوں', 'کے', 'کالج', 'میں', 'تھی', 'لیکن', 'ہم', 'دونوں', 'کیمبرج', 'یونیورسٹی', 'میں', 'ایک', 'ہی', 'مضمون', 'پڑھتے', 'تھےاس', 'لیے', 'اکثرلکچروں', 'میں', 'ملاقات', 'ہو', 'جاتی', 'تھیاس', 'کے', 'علاوہ', 'ہم', 'دوست', 'بھی', 'تھے', 'کئی', 'دلچسپیوں', 'میں', 'ایک', 'دوسرے', 'کے', 'شریک', 'ہوتے', 'تھے', 'تصویروں', 'اور', 'موسیقی', 'کاشوق', 'اسے', 'بھی', 'تھا', 'میں', 'بھی', 'ہمہدانی', 'کادعویدار', 'اکثرگیلریوں', 'یاکانسرٹوں', 'میں', 'اکھٹے', 'جایاکرتے', 'تھ', 'ہم', 'نے', 'کالج', 'میں', 'تعلیم', 'تو', 'ضرور', 'پائی', 'اور', 'رفتہ', 'رفتہ', 'بی', 'اے', 'بھی', 'پاس', 'کر', 'لی', 'ا', 'لیکن', 'اس', 'نصف', 'صدی', 'کے', 'دوران', 'جو', 'کالج', 'میں', 'گزارنی', 'پڑیہاسٹل', 'میں', 'داخل', 'ہونے', 'کی', 'اجازت', 'ہمیں', 'صرف', 'ایک', 'ہی', 'دفعہ', 'ملی', 'خدا', 'کا', 'یہ', 'فضل', 'ہم', 'پر', 'کب', 'اور', 'کس', 'طرح', 'ہوایہ', 'سوال', 'ایک', 'داستان', 'کا', 'محتاج', 'ہے', 'جب', 'ہم', 'نے', 'انٹرنس', 'پاس', 'کیا', 'تو', 'مقامی', 'اس', 'کول', 'کے', 'ہیڈ', 'ماسٹر', 'صاحب', 'خاص', 'طور', 'سے', 'مبارک', 'بعد', 'دینے', 'کے', 'لئ', 'از', 'لاہور', 'اے', 'میرے', 'کراچی', 'کے', 'دوست', 'چند', 'دن', 'ہوئے', 'میں', 'نے', 'اخبار', 'میں', 'یہ', 'خبر', 'پڑھی', 'کہ', 'کراچی', 'میں', 'فنون', 'لطیفہ', 'کی', 'ایک', 'انجمن', 'قائم', 'ہوئی', 'ہے', 'جو', 'وقتا', 'فوقتا', 'تصویروں', 'کی', 'نمائشوں', 'کا', 'اہتمام', 'کرے', 'گی', 'واضح', 'طور', 'پر', 'معلوم', 'نہ', 'ہو', 'سکا', 'کہ', 'اس', 'کے', 'کرتا', 'دھرتا', 'کو', 'ناہل', 'جنون', 'ہیں', 'لیکن', 'میں', 'جانتا', 'ہوں', 'کہ', 'آپ', 'کو', 'ای', 'سی', 'باتوں', 'کا', 'بے', 'انتہا', 'شوق', 'ہے', 'اور', 'مدت', 'سے', 'ہے', 'اور', 'آپ', 'ادب', 'اور', 'آرٹ', 'ک', 'گیدڑ', 'کی', 'موت', 'آتیہےتوشہر', 'کی', 'طرف', 'دوڑتاہے', 'ہماری', 'جوشامت', 'آئی', 'توایک', 'دن', 'اپنے', 'پڑوسی', 'لالہ', 'کرپاش', 'نکرجی', 'برہم', 'چاری', 'سے', 'برسبیل', 'تذکرہ', 'کہہ', 'بیٹھے', 'کہ', 'لالہ', 'جی', 'امتحان', 'کے', 'دن', 'قریب', 'آتے', 'جاتے', 'ہیںآپس', 'حرخیزہیںذراہمیںبھی', 'صبح', 'جگادیاکیجیئے', 'وہ', 'حضرت', 'بھی', 'معلوم', 'ہوتاہےلفظوںکے', 'بھوکے', 'بیٹھے', 'تھے', 'دوسرے', 'دن', 'اٹھتے', 'ہی', 'انھوںنے', 'ایشورکا', 'نام', 'لے', 'کرہما', 'سینما', 'کا', 'عشق', 'عنوان', 'تو', 'عجب', 'ہوس', 'خیزہے', 'لیکن', 'افسوس', 'کہ', 'اس', 'مضمون', 'سے', 'آپ', 'کی', 'تمام', 'توقعات', 'مجروح', 'ہوںگی', 'کیونکہ', 'مجھے', 'تو', 'اس', 'مضمون', 'میں', 'کچھ', 'دل', 'کے', 'داغ', 'دکھانے', 'مقصود', 'ہیں', 'اس', 'سے', 'آپ', 'یہ', 'نہ', 'سمجھئے', 'کہ', 'مجھے', 'فلموں', 'سے', 'دلچسپی', 'نہیں', 'یا', 'سینماکی', 'موسیقی', 'اورتاریکی', 'میں', 'جوارمان', 'انگیز', 'یہے', 'میں', 'اس', 'کا', 'قائل', 'نہیں', 'میں', 'تو', 'سینماکے', 'معاملے', 'میں', 'اوائل', 'عمر', 'ہی', 'سے', 'بزرگ', 'تمہید', 'تمہید', 'کے', 'طور', 'پر', 'صرف', 'اتنا', 'عرض', 'کرنا', 'چاہتا', 'ہوں', 'کہ', 'لاہور', 'کو', 'دریافت', 'ہوئے', 'اب', 'بہت', 'عرصہ', 'گزر', 'چکا', 'ہے', 'اس', 'لیے', 'دلائل', 'وبراہین', 'سے', 'اس', 'کے', 'وجود', 'کو', 'ثابت', 'کرنے', 'کی', 'ضرورت', 'نہیں', 'یہ', 'کہنے', 'کی', 'اب', 'ضرورت', 'نہیں', 'کہ', 'کرے', 'کو', 'دائیں', 'سے', 'بائیں', 'گھمائیے', 'حتی', 'کہ', 'ہندوستان', 'کا', 'ملک', 'آپ', 'کے', 'سامنے', 'آکر', 'ٹھہر', 'جائے', 'پھر', 'فلاں', 'طول', 'البلد', 'اور', 'فلاں', 'عرض', 'البلد', 'کے', 'مقام', 'انقطاع', 'پر', 'لاہ']
# 409

# %% [markdown]
# ## Creating Unigrams
#
# Generate a list of unigrams. Print the first 10 unigrams obtained.

# %%
# code here
from nltk.util import ngrams
unigrams = list(ngrams(preprocessed_tokens, 1))

print('First 10 unigrams')
for i in range(10):
    print(unigrams[i])
# Out:
# First 10 unigrams
# ('میبل',)
# ('لڑکیوں',)
# ('کے',)
# ('کالج',)
# ('میں',)
# ('تھی',)
# ('لیکن',)
# ('ہم',)
# ('دونوں',)
# ('کیمبرج',)

# %% [markdown]
# Find the probabilities for each unique unigram. (Refer to the Shannon Visualization Method that we studied in class.)

# %%
# code here
# Calculating the probabilties of each unigram
from nltk import FreqDist
frequency_unigrams = FreqDist(unigrams)
no_of_unigrams = len(unigrams)

#creating a dictionary for storing probabilties
probabilties={}
for unigram, freq in frequency_unigrams.items():
    probabilties[unigram[0]]=(freq/no_of_unigrams)
    print('Unigram:', unigram[0], " Probability: " ,freq/no_of_unigrams)
# Out:
# Unigram: میبل  Probability:  0.0024449877750611247
# Unigram: لڑکیوں  Probability:  0.0024449877750611247
# Unigram: کے  Probability:  0.034229828850855744
# Unigram: کالج  Probability:  0.007334963325183374
# Unigram: میں  Probability:  0.044009779951100246
# Unigram: تھی  Probability:  0.0024449877750611247
# Unigram: لیکن  Probability:  0.009779951100244499
# Unigram: ہم  Probability:  0.012224938875305624
# Unigram: دونوں  Probability:  0.0024449877750611247
# Unigram: کیمبرج  Probability:  0.0024449877750611247
# Unigram: یونیورسٹی  Probability:  0.0024449877750611247
# Unigram: ایک  Probability:  0.012224938875305624
# Unigram: ہی  Probability:  0.009779951100244499
# Unigram: مضمون  Probability:  0.007334963325183374
# Unigram: پڑھتے  Probability:  0.0024449877750611247
# Unigram: تھےاس  Probability:  0.0024449877750611247
# Unigram: لیے  Probability:  0.004889975550122249
# Unigram: اکثرلکچروں  Probability:  0.0024449877750611247
# Unigram: ملاقات  Probability:  0.0024449877750611247
# Unigram: ہو  Probability:  0.004889975550122249
# Unigram: جاتی  Probability:  0.0024449877750611247
# Unigram: تھیاس  Probability:  0.0024449877750611247
# Unigram: علاوہ  Probability:  0.0024449877750611247
# Unigram: دوست  Probability:  0.004889975550122249
# Unigram: بھی  Probability:  0.012224938875305624
# Unigram: تھے  Probability:  0.007334963325183374
# Unigram: کئی  Probability:  0.0024449877750611247
# Unigram: دلچسپیوں  Probability:  0.0024449877750611247
# Unigram: دوسرے  Probability:  0.004889975550122249
# Unigram: شریک  Probability:  0.0024449877750611247
# Unigram: ہوتے  Probability:  0.0024449877750611247
# Unigram: تصویروں  Probability:  0.004889975550122249
# Unigram: اور  Probability:  0.017114914425427872
# Unigram: موسیقی  Probability:  0.004889975550122249
# Unigram: کاشوق  Probability:  0.0024449877750611247
# Unigram: اسے  Probability:  0.0024449877750611247
# Unigram: تھا  Probability:  0.0024449877750611247
# Unigram: ہمہدانی  Probability:  0.0024449877750611247
# Unigram: کادعویدار  Probability:  0.0024449877750611247
# Unigram: اکثرگیلریوں  Probability:  0.0024449877750611247
# Unigram: یاکانسرٹوں  Probability:  0.0024449877750611247
# Unigram: اکھٹے  Probability:  0.0024449877750611247
# Unigram: جایاکرتے  Probability:  0.0024449877750611247
# Unigram: تھ  Probability:  0.0024449877750611247
# Unigram: نے  Probability:  0.007334963325183374
# Unigram: تعلیم  Probability:  0.0024449877750611247
# Unigram: تو  Probability:  0.012224938875305624
# Unigram: ضرور  Probability:  0.0024449877750611247
# Unigram: پائی  Probability:  0.0024449877750611247
# Unigram: رفتہ  Probability:  0.004889975550122249
# Unigram: بی  Probability:  0.0024449877750611247
# Unigram: اے  Probability:  0.004889975550122249
# Unigram: پاس  Probability:  0.004889975550122249
# Unigram: کر  Probability:  0.0024449877750611247
# Unigram: لی  Probability:  0.0024449877750611247
# Unigram: ا  Probability:  0.0024449877750611247
# Unigram: اس  Probability:  0.022004889975550123
# Unigram: نصف  Probability:  0.0024449877750611247
# Unigram: صدی  Probability:  0.0024449877750611247
# Unigram: دوران  Probability:  0.0024449877750611247
# Unigram: جو  Probability:  0.004889975550122249
# Unigram: گزارنی  Probability:  0.0024449877750611247
# Unigram: پڑیہاسٹل  Probability:  0.0024449877750611247
# Unigram: داخل  Probability:  0.0024449877750611247
# Unigram: ہونے  Probability:  0.0024449877750611247
# Unigram: کی  Probability:  0.019559902200488997
# Unigram: اجازت  Probability:  0.0024449877750611247
# Unigram: ہمیں  Probability:  0.0024449877750611247
# Unigram: صرف  Probability:  0.004889975550122249
# Unigram: دفعہ  Probability:  0.0024449877750611247
# Unigram: ملی  Probability:  0.0024449877750611247
# Unigram: خدا  Probability:  0.0024449877750611247
# Unigram: کا  Probability:  0.017114914425427872
# Unigram: یہ  Probability:  0.009779951100244499
# Unigram: فضل  Probability:  0.0024449877750611247
# Unigram: پر  Probability:  0.009779951100244499
# Unigram: کب  Probability:  0.0024449877750611247
# Unigram: کس  Probability:  0.0024449877750611247
# Unigram: طرح  Probability:  0.0024449877750611247
# Unigram: ہوایہ  Probability:  0.0024449877750611247
# Unigram: سوال  Probability:  0.0024449877750611247
# Unigram: داستان  Probability:  0.0024449877750611247
# Unigram: محتاج  Probability:  0.0024449877750611247
# Unigram: ہے  Probability:  0.012224938875305624
# Unigram: جب  Probability:  0.0024449877750611247
# Unigram: انٹرنس  Probability:  0.0024449877750611247
# Unigram: کیا  Probability:  0.0024449877750611247
# Unigram: مقامی  Probability:  0.0024449877750611247
# Unigram: کول  Probability:  0.0024449877750611247
# Unigram: ہیڈ  Probability:  0.0024449877750611247
# Unigram: ماسٹر  Probability:  0.0024449877750611247
# Unigram: صاحب  Probability:  0.0024449877750611247
# Unigram: خاص  Probability:  0.0024449877750611247
# Unigram: طور  Probability:  0.007334963325183374
# Unigram: سے  Probability:  0.022004889975550123
# Unigram: مبارک  Probability:  0.0024449877750611247
# Unigram: بعد  Probability:  0.0024449877750611247
# Unigram: دینے  Probability:  0.0024449877750611247
# Unigram: لئ  Probability:  0.0024449877750611247
# Unigram: از  Probability:  0.0024449877750611247
# Unigram: لاہور  Probability:  0.004889975550122249
# Unigram: میرے  Probability:  0.0024449877750611247
# Unigram: کراچی  Probability:  0.004889975550122249
# Unigram: چند  Probability:  0.0024449877750611247
# Unigram: دن  Probability:  0.009779951100244499
# Unigram: ہوئے  Probability:  0.004889975550122249
# Unigram: اخبار  Probability:  0.0024449877750611247
# Unigram: خبر  Probability:  0.0024449877750611247
# Unigram: پڑھی  Probability:  0.0024449877750611247
# Unigram: کہ  Probability:  0.022004889975550123
# Unigram: فنون  Probability:  0.0024449877750611247
# Unigram: لطیفہ  Probability:  0.0024449877750611247
# Unigram: انجمن  Probability:  0.0024449877750611247
# Unigram: قائم  Probability:  0.0024449877750611247
# Unigram: ہوئی  Probability:  0.0024449877750611247
# Unigram: وقتا  Probability:  0.0024449877750611247
# Unigram: فوقتا  Probability:  0.0024449877750611247
# Unigram: نمائشوں  Probability:  0.0024449877750611247
# Unigram: اہتمام  Probability:  0.0024449877750611247
# Unigram: کرے  Probability:  0.004889975550122249
# Unigram: گی  Probability:  0.0024449877750611247
# Unigram: واضح  Probability:  0.0024449877750611247
# Unigram: معلوم  Probability:  0.004889975550122249
# Unigram: نہ  Probability:  0.004889975550122249
# Unigram: سکا  Probability:  0.0024449877750611247
# Unigram: کرتا  Probability:  0.0024449877750611247
# Unigram: دھرتا  Probability:  0.0024449877750611247
# Unigram: کو  Probability:  0.012224938875305624
# Unigram: ناہل  Probability:  0.0024449877750611247
# Unigram: جنون  Probability:  0.0024449877750611247
# Unigram: ہیں  Probability:  0.004889975550122249
# Unigram: جانتا  Probability:  0.0024449877750611247
# Unigram: ہوں  Probability:  0.004889975550122249
# Unigram: آپ  Probability:  0.012224938875305624
# Unigram: ای  Probability:  0.0024449877750611247
# Unigram: سی  Probability:  0.0024449877750611247
# Unigram: باتوں  Probability:  0.0024449877750611247
# Unigram: بے  Probability:  0.0024449877750611247
# Unigram: انتہا  Probability:  0.0024449877750611247
# Unigram: شوق  Probability:  0.0024449877750611247
# Unigram: مدت  Probability:  0.0024449877750611247
# Unigram: ادب  Probability:  0.0024449877750611247
# Unigram: آرٹ  Probability:  0.0024449877750611247
# Unigram: ک  Probability:  0.0024449877750611247
# Unigram: گیدڑ  Probability:  0.0024449877750611247
# Unigram: موت  Probability:  0.0024449877750611247
# Unigram: آتیہےتوشہر  Probability:  0.0024449877750611247
# Unigram: طرف  Probability:  0.0024449877750611247
# Unigram: دوڑتاہے  Probability:  0.0024449877750611247
# Unigram: ہماری  Probability:  0.0024449877750611247
# Unigram: جوشامت  Probability:  0.0024449877750611247
# Unigram: آئی  Probability:  0.0024449877750611247
# Unigram: توایک  Probability:  0.0024449877750611247
# Unigram: اپنے  Probability:  0.0024449877750611247
# Unigram: پڑوسی  Probability:  0.0024449877750611247
# Unigram: لالہ  Probability:  0.004889975550122249
# Unigram: کرپاش  Probability:  0.0024449877750611247
# Unigram: نکرجی  Probability:  0.0024449877750611247
# Unigram: برہم  Probability:  0.0024449877750611247
# Unigram: چاری  Probability:  0.0024449877750611247
# Unigram: برسبیل  Probability:  0.0024449877750611247
# Unigram: تذکرہ  Probability:  0.0024449877750611247
# Unigram: کہہ  Probability:  0.0024449877750611247
# Unigram: بیٹھے  Probability:  0.004889975550122249
# Unigram: جی  Probability:  0.0024449877750611247
# Unigram: امتحان  Probability:  0.0024449877750611247
# Unigram: قریب  Probability:  0.0024449877750611247
# Unigram: آتے  Probability:  0.0024449877750611247
# Unigram: جاتے  Probability:  0.0024449877750611247
# Unigram: ہیںآپس  Probability:  0.0024449877750611247
# Unigram: حرخیزہیںذراہمیںبھی  Probability:  0.0024449877750611247
# Unigram: صبح  Probability:  0.0024449877750611247
# Unigram: جگادیاکیجیئے  Probability:  0.0024449877750611247
# Unigram: وہ  Probability:  0.0024449877750611247
# Unigram: حضرت  Probability:  0.0024449877750611247
# Unigram: ہوتاہےلفظوںکے  Probability:  0.0024449877750611247
# Unigram: بھوکے  Probability:  0.0024449877750611247
# Unigram: اٹھتے  Probability:  0.0024449877750611247
# Unigram: انھوںنے  Probability:  0.0024449877750611247
# Unigram: ایشورکا  Probability:  0.0024449877750611247
# Unigram: نام  Probability:  0.0024449877750611247
# Unigram: لے  Probability:  0.0024449877750611247
# Unigram: کرہما  Probability:  0.0024449877750611247
# Unigram: سینما  Probability:  0.0024449877750611247
# Unigram: عشق  Probability:  0.0024449877750611247
# Unigram: عنوان  Probability:  0.0024449877750611247
# Unigram: عجب  Probability:  0.0024449877750611247
# Unigram: ہوس  Probability:  0.0024449877750611247
# Unigram: خیزہے  Probability:  0.0024449877750611247
# Unigram: افسوس  Probability:  0.0024449877750611247
# Unigram: تمام  Probability:  0.0024449877750611247
# Unigram: توقعات  Probability:  0.0024449877750611247
# Unigram: مجروح  Probability:  0.0024449877750611247
# Unigram: ہوںگی  Probability:  0.0024449877750611247
# Unigram: کیونکہ  Probability:  0.0024449877750611247
# Unigram: مجھے  Probability:  0.004889975550122249
# Unigram: کچھ  Probability:  0.0024449877750611247
# Unigram: دل  Probability:  0.0024449877750611247
# Unigram: داغ  Probability:  0.0024449877750611247
# Unigram: دکھانے  Probability:  0.0024449877750611247
# Unigram: مقصود  Probability:  0.0024449877750611247
# Unigram: سمجھئے  Probability:  0.0024449877750611247
# Unigram: فلموں  Probability:  0.0024449877750611247
# Unigram: دلچسپی  Probability:  0.0024449877750611247
# Unigram: نہیں  Probability:  0.009779951100244499
# Unigram: یا  Probability:  0.0024449877750611247
# Unigram: سینماکی  Probability:  0.0024449877750611247
# Unigram: اورتاریکی  Probability:  0.0024449877750611247
# Unigram: جوارمان  Probability:  0.0024449877750611247
# Unigram: انگیز  Probability:  0.0024449877750611247
# Unigram: یہے  Probability:  0.0024449877750611247
# Unigram: قائل  Probability:  0.0024449877750611247
# Unigram: سینماکے  Probability:  0.0024449877750611247
# Unigram: معاملے  Probability:  0.0024449877750611247
# Unigram: اوائل  Probability:  0.0024449877750611247
# Unigram: عمر  Probability:  0.0024449877750611247
# Unigram: بزرگ  Probability:  0.0024449877750611247
# Unigram: تمہید  Probability:  0.004889975550122249
# Unigram: اتنا  Probability:  0.0024449877750611247
# Unigram: عرض  Probability:  0.004889975550122249
# Unigram: کرنا  Probability:  0.0024449877750611247
# Unigram: چاہتا  Probability:  0.0024449877750611247
# Unigram: دریافت  Probability:  0.0024449877750611247
# Unigram: اب  Probability:  0.004889975550122249
# Unigram: بہت  Probability:  0.0024449877750611247
# Unigram: عرصہ  Probability:  0.0024449877750611247
# Unigram: گزر  Probability:  0.0024449877750611247
# Unigram: چکا  Probability:  0.0024449877750611247
# Unigram: دلائل  Probability:  0.0024449877750611247
# Unigram: وبراہین  Probability:  0.0024449877750611247
# Unigram: وجود  Probability:  0.0024449877750611247
# Unigram: ثابت  Probability:  0.0024449877750611247
# Unigram: کرنے  Probability:  0.0024449877750611247
# Unigram: ضرورت  Probability:  0.004889975550122249
# Unigram: کہنے  Probability:  0.0024449877750611247
# Unigram: دائیں  Probability:  0.0024449877750611247
# Unigram: بائیں  Probability:  0.0024449877750611247
# Unigram: گھمائیے  Probability:  0.0024449877750611247
# Unigram: حتی  Probability:  0.0024449877750611247
# Unigram: ہندوستان  Probability:  0.0024449877750611247
# Unigram: ملک  Probability:  0.0024449877750611247
# Unigram: سامنے  Probability:  0.0024449877750611247
# Unigram: آکر  Probability:  0.0024449877750611247
# Unigram: ٹھہر  Probability:  0.0024449877750611247
# Unigram: جائے  Probability:  0.0024449877750611247
# Unigram: پھر  Probability:  0.0024449877750611247
# Unigram: فلاں  Probability:  0.004889975550122249
# Unigram: طول  Probability:  0.0024449877750611247
# Unigram: البلد  Probability:  0.004889975550122249
# Unigram: مقام  Probability:  0.0024449877750611247
# Unigram: انقطاع  Probability:  0.0024449877750611247
# Unigram: لاہ  Probability:  0.0024449877750611247

# %% [markdown]
# ## Creating Bigrams
#
# Generate a list of bigrams. Print the first 10 bigrams obtained.

# %%
from nltk.util import ngrams
bigrams = list(ngrams(preprocessed_tokens, 2))

print('First 10 bigrams')
for i in range(10):
    print(bigrams[i])
# Out:
# First 10 bigrams
# ('میبل', 'لڑکیوں')
# ('لڑکیوں', 'کے')
# ('کے', 'کالج')
# ('کالج', 'میں')
# ('میں', 'تھی')
# ('تھی', 'لیکن')
# ('لیکن', 'ہم')
# ('ہم', 'دونوں')
# ('دونوں', 'کیمبرج')
# ('کیمبرج', 'یونیورسٹی')

# %% [markdown]
# Find the probabilities for each unique bigram.

# %%
# code here
# Calculating the probabilties of each bigram
from nltk import FreqDist
frequency = FreqDist(bigrams)
no_of_bigrams = len(bigrams)

#creating a dictionary for storing probabilties
probabilties_bigrams={}
for bigram, freq in frequency.items():
    individual_bigram_probability = (freq/(no_of_bigrams+1))
    unigram_probability=probabilties[bigram[0]]
    probabilties_bigrams[bigram]= individual_bigram_probability/unigram_probability
    print('Bigram:', bigram, " Probability: " ,individual_bigram_probability/unigram_probability)
# Out:
# Bigram: ('میبل', 'لڑکیوں')  Probability:  1.0
# Bigram: ('لڑکیوں', 'کے')  Probability:  1.0
# Bigram: ('کے', 'کالج')  Probability:  0.07142857142857144
# Bigram: ('کالج', 'میں')  Probability:  1.0
# Bigram: ('میں', 'تھی')  Probability:  0.05555555555555555
# Bigram: ('تھی', 'لیکن')  Probability:  1.0
# Bigram: ('لیکن', 'ہم')  Probability:  0.25
# Bigram: ('ہم', 'دونوں')  Probability:  0.19999999999999998
# Bigram: ('دونوں', 'کیمبرج')  Probability:  1.0
# Bigram: ('کیمبرج', 'یونیورسٹی')  Probability:  1.0
# Bigram: ('یونیورسٹی', 'میں')  Probability:  1.0
# Bigram: ('میں', 'ایک')  Probability:  0.1111111111111111
# Bigram: ('ایک', 'ہی')  Probability:  0.39999999999999997
# Bigram: ('ہی', 'مضمون')  Probability:  0.25
# Bigram: ('مضمون', 'پڑھتے')  Probability:  0.3333333333333333
# Bigram: ('پڑھتے', 'تھےاس')  Probability:  1.0
# Bigram: ('تھےاس', 'لیے')  Probability:  1.0
# Bigram: ('لیے', 'اکثرلکچروں')  Probability:  0.5
# Bigram: ('اکثرلکچروں', 'میں')  Probability:  1.0
# Bigram: ('میں', 'ملاقات')  Probability:  0.05555555555555555
# Bigram: ('ملاقات', 'ہو')  Probability:  1.0
# Bigram: ('ہو', 'جاتی')  Probability:  0.5
# Bigram: ('جاتی', 'تھیاس')  Probability:  1.0
# Bigram: ('تھیاس', 'کے')  Probability:  1.0
# Bigram: ('کے', 'علاوہ')  Probability:  0.07142857142857144
# Bigram: ('علاوہ', 'ہم')  Probability:  1.0
# Bigram: ('ہم', 'دوست')  Probability:  0.19999999999999998
# Bigram: ('دوست', 'بھی')  Probability:  0.5
# Bigram: ('بھی', 'تھے')  Probability:  0.19999999999999998
# Bigram: ('تھے', 'کئی')  Probability:  0.3333333333333333
# Bigram: ('کئی', 'دلچسپیوں')  Probability:  1.0
# Bigram: ('دلچسپیوں', 'میں')  Probability:  1.0
# Bigram: ('ایک', 'دوسرے')  Probability:  0.19999999999999998
# Bigram: ('دوسرے', 'کے')  Probability:  0.5
# Bigram: ('کے', 'شریک')  Probability:  0.07142857142857144
# Bigram: ('شریک', 'ہوتے')  Probability:  1.0
# Bigram: ('ہوتے', 'تھے')  Probability:  1.0
# Bigram: ('تھے', 'تصویروں')  Probability:  0.3333333333333333
# Bigram: ('تصویروں', 'اور')  Probability:  0.5
# Bigram: ('اور', 'موسیقی')  Probability:  0.14285714285714288
# Bigram: ('موسیقی', 'کاشوق')  Probability:  0.5
# Bigram: ('کاشوق', 'اسے')  Probability:  1.0
# Bigram: ('اسے', 'بھی')  Probability:  1.0
# Bigram: ('بھی', 'تھا')  Probability:  0.19999999999999998
# Bigram: ('تھا', 'میں')  Probability:  1.0
# Bigram: ('میں', 'بھی')  Probability:  0.05555555555555555
# Bigram: ('بھی', 'ہمہدانی')  Probability:  0.19999999999999998
# Bigram: ('ہمہدانی', 'کادعویدار')  Probability:  1.0
# Bigram: ('کادعویدار', 'اکثرگیلریوں')  Probability:  1.0
# Bigram: ('اکثرگیلریوں', 'یاکانسرٹوں')  Probability:  1.0
# Bigram: ('یاکانسرٹوں', 'میں')  Probability:  1.0
# Bigram: ('میں', 'اکھٹے')  Probability:  0.05555555555555555
# Bigram: ('اکھٹے', 'جایاکرتے')  Probability:  1.0
# Bigram: ('جایاکرتے', 'تھ')  Probability:  1.0
# Bigram: ('تھ', 'ہم')  Probability:  1.0
# Bigram: ('ہم', 'نے')  Probability:  0.39999999999999997
# Bigram: ('نے', 'کالج')  Probability:  0.3333333333333333
# Bigram: ('میں', 'تعلیم')  Probability:  0.05555555555555555
# Bigram: ('تعلیم', 'تو')  Probability:  1.0
# Bigram: ('تو', 'ضرور')  Probability:  0.19999999999999998
# Bigram: ('ضرور', 'پائی')  Probability:  1.0
# Bigram: ('پائی', 'اور')  Probability:  1.0
# Bigram: ('اور', 'رفتہ')  Probability:  0.14285714285714288
# Bigram: ('رفتہ', 'رفتہ')  Probability:  0.5
# Bigram: ('رفتہ', 'بی')  Probability:  0.5
# Bigram: ('بی', 'اے')  Probability:  1.0
# Bigram: ('اے', 'بھی')  Probability:  0.5
# Bigram: ('بھی', 'پاس')  Probability:  0.19999999999999998
# Bigram: ('پاس', 'کر')  Probability:  0.5
# Bigram: ('کر', 'لی')  Probability:  1.0
# Bigram: ('لی', 'ا')  Probability:  1.0
# Bigram: ('ا', 'لیکن')  Probability:  1.0
# Bigram: ('لیکن', 'اس')  Probability:  0.25
# Bigram: ('اس', 'نصف')  Probability:  0.1111111111111111
# Bigram: ('نصف', 'صدی')  Probability:  1.0
# Bigram: ('صدی', 'کے')  Probability:  1.0
# Bigram: ('کے', 'دوران')  Probability:  0.07142857142857144
# Bigram: ('دوران', 'جو')  Probability:  1.0
# Bigram: ('جو', 'کالج')  Probability:  0.5
# Bigram: ('میں', 'گزارنی')  Probability:  0.05555555555555555
# Bigram: ('گزارنی', 'پڑیہاسٹل')  Probability:  1.0
# Bigram: ('پڑیہاسٹل', 'میں')  Probability:  1.0
# Bigram: ('میں', 'داخل')  Probability:  0.05555555555555555
# Bigram: ('داخل', 'ہونے')  Probability:  1.0
# Bigram: ('ہونے', 'کی')  Probability:  1.0
# Bigram: ('کی', 'اجازت')  Probability:  0.125
# Bigram: ('اجازت', 'ہمیں')  Probability:  1.0
# Bigram: ('ہمیں', 'صرف')  Probability:  1.0
# Bigram: ('صرف', 'ایک')  Probability:  0.5
# Bigram: ('ہی', 'دفعہ')  Probability:  0.25
# Bigram: ('دفعہ', 'ملی')  Probability:  1.0
# Bigram: ('ملی', 'خدا')  Probability:  1.0
# Bigram: ('خدا', 'کا')  Probability:  1.0
# Bigram: ('کا', 'یہ')  Probability:  0.14285714285714288
# Bigram: ('یہ', 'فضل')  Probability:  0.25
# Bigram: ('فضل', 'ہم')  Probability:  1.0
# Bigram: ('ہم', 'پر')  Probability:  0.19999999999999998
# Bigram: ('پر', 'کب')  Probability:  0.25
# Bigram: ('کب', 'اور')  Probability:  1.0
# Bigram: ('اور', 'کس')  Probability:  0.14285714285714288
# Bigram: ('کس', 'طرح')  Probability:  1.0
# Bigram: ('طرح', 'ہوایہ')  Probability:  1.0
# Bigram: ('ہوایہ', 'سوال')  Probability:  1.0
# Bigram: ('سوال', 'ایک')  Probability:  1.0
# Bigram: ('ایک', 'داستان')  Probability:  0.19999999999999998
# Bigram: ('داستان', 'کا')  Probability:  1.0
# Bigram: ('کا', 'محتاج')  Probability:  0.14285714285714288
# Bigram: ('محتاج', 'ہے')  Probability:  1.0
# Bigram: ('ہے', 'جب')  Probability:  0.19999999999999998
# Bigram: ('جب', 'ہم')  Probability:  1.0
# Bigram: ('نے', 'انٹرنس')  Probability:  0.3333333333333333
# Bigram: ('انٹرنس', 'پاس')  Probability:  1.0
# Bigram: ('پاس', 'کیا')  Probability:  0.5
# Bigram: ('کیا', 'تو')  Probability:  1.0
# Bigram: ('تو', 'مقامی')  Probability:  0.19999999999999998
# Bigram: ('مقامی', 'اس')  Probability:  1.0
# Bigram: ('اس', 'کول')  Probability:  0.1111111111111111
# Bigram: ('کول', 'کے')  Probability:  1.0
# Bigram: ('کے', 'ہیڈ')  Probability:  0.07142857142857144
# Bigram: ('ہیڈ', 'ماسٹر')  Probability:  1.0
# Bigram: ('ماسٹر', 'صاحب')  Probability:  1.0
# Bigram: ('صاحب', 'خاص')  Probability:  1.0
# Bigram: ('خاص', 'طور')  Probability:  1.0
# Bigram: ('طور', 'سے')  Probability:  0.3333333333333333
# Bigram: ('سے', 'مبارک')  Probability:  0.1111111111111111
# Bigram: ('مبارک', 'بعد')  Probability:  1.0
# Bigram: ('بعد', 'دینے')  Probability:  1.0
# Bigram: ('دینے', 'کے')  Probability:  1.0
# Bigram: ('کے', 'لئ')  Probability:  0.07142857142857144
# Bigram: ('لئ', 'از')  Probability:  1.0
# Bigram: ('از', 'لاہور')  Probability:  1.0
# Bigram: ('لاہور', 'اے')  Probability:  0.5
# Bigram: ('اے', 'میرے')  Probability:  0.5
# Bigram: ('میرے', 'کراچی')  Probability:  1.0
# Bigram: ('کراچی', 'کے')  Probability:  0.5
# Bigram: ('کے', 'دوست')  Probability:  0.07142857142857144
# Bigram: ('دوست', 'چند')  Probability:  0.5
# Bigram: ('چند', 'دن')  Probability:  1.0
# Bigram: ('دن', 'ہوئے')  Probability:  0.25
# Bigram: ('ہوئے', 'میں')  Probability:  0.5
# Bigram: ('میں', 'نے')  Probability:  0.05555555555555555
# Bigram: ('نے', 'اخبار')  Probability:  0.3333333333333333
# Bigram: ('اخبار', 'میں')  Probability:  1.0
# Bigram: ('میں', 'یہ')  Probability:  0.05555555555555555
# Bigram: ('یہ', 'خبر')  Probability:  0.25
# Bigram: ('خبر', 'پڑھی')  Probability:  1.0
# Bigram: ('پڑھی', 'کہ')  Probability:  1.0
# Bigram: ('کہ', 'کراچی')  Probability:  0.1111111111111111
# Bigram: ('کراچی', 'میں')  Probability:  0.5
# Bigram: ('میں', 'فنون')  Probability:  0.05555555555555555
# Bigram: ('فنون', 'لطیفہ')  Probability:  1.0
# Bigram: ('لطیفہ', 'کی')  Probability:  1.0
# Bigram: ('کی', 'ایک')  Probability:  0.125
# Bigram: ('ایک', 'انجمن')  Probability:  0.19999999999999998
# Bigram: ('انجمن', 'قائم')  Probability:  1.0
# Bigram: ('قائم', 'ہوئی')  Probability:  1.0
# Bigram: ('ہوئی', 'ہے')  Probability:  1.0
# Bigram: ('ہے', 'جو')  Probability:  0.19999999999999998
# Bigram: ('جو', 'وقتا')  Probability:  0.5
# Bigram: ('وقتا', 'فوقتا')  Probability:  1.0
# Bigram: ('فوقتا', 'تصویروں')  Probability:  1.0
# Bigram: ('تصویروں', 'کی')  Probability:  0.5
# Bigram: ('کی', 'نمائشوں')  Probability:  0.125
# Bigram: ('نمائشوں', 'کا')  Probability:  1.0
# Bigram: ('کا', 'اہتمام')  Probability:  0.14285714285714288
# Bigram: ('اہتمام', 'کرے')  Probability:  1.0
# Bigram: ('کرے', 'گی')  Probability:  0.5
# Bigram: ('گی', 'واضح')  Probability:  1.0
# Bigram: ('واضح', 'طور')  Probability:  1.0
# Bigram: ('طور', 'پر')  Probability:  0.6666666666666666
# Bigram: ('پر', 'معلوم')  Probability:  0.25
# Bigram: ('معلوم', 'نہ')  Probability:  0.5
# Bigram: ('نہ', 'ہو')  Probability:  0.5
# Bigram: ('ہو', 'سکا')  Probability:  0.5
# Bigram: ('سکا', 'کہ')  Probability:  1.0
# Bigram: ('کہ', 'اس')  Probability:  0.2222222222222222
# Bigram: ('اس', 'کے')  Probability:  0.2222222222222222
# Bigram: ('کے', 'کرتا')  Probability:  0.07142857142857144
# Bigram: ('کرتا', 'دھرتا')  Probability:  1.0
# Bigram: ('دھرتا', 'کو')  Probability:  1.0
# Bigram: ('کو', 'ناہل')  Probability:  0.19999999999999998
# Bigram: ('ناہل', 'جنون')  Probability:  1.0
# Bigram: ('جنون', 'ہیں')  Probability:  1.0
# Bigram: ('ہیں', 'لیکن')  Probability:  0.5
# Bigram: ('لیکن', 'میں')  Probability:  0.25
# Bigram: ('میں', 'جانتا')  Probability:  0.05555555555555555
# Bigram: ('جانتا', 'ہوں')  Probability:  1.0
# Bigram: ('ہوں', 'کہ')  Probability:  1.0
# Bigram: ('کہ', 'آپ')  Probability:  0.1111111111111111
# Bigram: ('آپ', 'کو')  Probability:  0.19999999999999998
# Bigram: ('کو', 'ای')  Probability:  0.19999999999999998
# Bigram: ('ای', 'سی')  Probability:  1.0
# Bigram: ('سی', 'باتوں')  Probability:  1.0
# Bigram: ('باتوں', 'کا')  Probability:  1.0
# Bigram: ('کا', 'بے')  Probability:  0.14285714285714288
# Bigram: ('بے', 'انتہا')  Probability:  1.0
# Bigram: ('انتہا', 'شوق')  Probability:  1.0
# Bigram: ('شوق', 'ہے')  Probability:  1.0
# Bigram: ('ہے', 'اور')  Probability:  0.39999999999999997
# Bigram: ('اور', 'مدت')  Probability:  0.14285714285714288
# Bigram: ('مدت', 'سے')  Probability:  1.0
# Bigram: ('سے', 'ہے')  Probability:  0.1111111111111111
# Bigram: ('اور', 'آپ')  Probability:  0.14285714285714288
# Bigram: ('آپ', 'ادب')  Probability:  0.19999999999999998
# Bigram: ('ادب', 'اور')  Probability:  1.0
# Bigram: ('اور', 'آرٹ')  Probability:  0.14285714285714288
# Bigram: ('آرٹ', 'ک')  Probability:  1.0
# Bigram: ('ک', 'گیدڑ')  Probability:  1.0
# Bigram: ('گیدڑ', 'کی')  Probability:  1.0
# Bigram: ('کی', 'موت')  Probability:  0.125
# Bigram: ('موت', 'آتیہےتوشہر')  Probability:  1.0
# Bigram: ('آتیہےتوشہر', 'کی')  Probability:  1.0
# Bigram: ('کی', 'طرف')  Probability:  0.125
# Bigram: ('طرف', 'دوڑتاہے')  Probability:  1.0
# Bigram: ('دوڑتاہے', 'ہماری')  Probability:  1.0
# Bigram: ('ہماری', 'جوشامت')  Probability:  1.0
# Bigram: ('جوشامت', 'آئی')  Probability:  1.0
# Bigram: ('آئی', 'توایک')  Probability:  1.0
# Bigram: ('توایک', 'دن')  Probability:  1.0
# Bigram: ('دن', 'اپنے')  Probability:  0.25
# Bigram: ('اپنے', 'پڑوسی')  Probability:  1.0
# Bigram: ('پڑوسی', 'لالہ')  Probability:  1.0
# Bigram: ('لالہ', 'کرپاش')  Probability:  0.5
# Bigram: ('کرپاش', 'نکرجی')  Probability:  1.0
# Bigram: ('نکرجی', 'برہم')  Probability:  1.0
# Bigram: ('برہم', 'چاری')  Probability:  1.0
# Bigram: ('چاری', 'سے')  Probability:  1.0
# Bigram: ('سے', 'برسبیل')  Probability:  0.1111111111111111
# Bigram: ('برسبیل', 'تذکرہ')  Probability:  1.0
# Bigram: ('تذکرہ', 'کہہ')  Probability:  1.0
# Bigram: ('کہہ', 'بیٹھے')  Probability:  1.0
# Bigram: ('بیٹھے', 'کہ')  Probability:  0.5
# Bigram: ('کہ', 'لالہ')  Probability:  0.1111111111111111
# Bigram: ('لالہ', 'جی')  Probability:  0.5
# Bigram: ('جی', 'امتحان')  Probability:  1.0
# Bigram: ('امتحان', 'کے')  Probability:  1.0
# Bigram: ('کے', 'دن')  Probability:  0.07142857142857144
# Bigram: ('دن', 'قریب')  Probability:  0.25
# Bigram: ('قریب', 'آتے')  Probability:  1.0
# Bigram: ('آتے', 'جاتے')  Probability:  1.0
# Bigram: ('جاتے', 'ہیںآپس')  Probability:  1.0
# Bigram: ('ہیںآپس', 'حرخیزہیںذراہمیںبھی')  Probability:  1.0
# Bigram: ('حرخیزہیںذراہمیںبھی', 'صبح')  Probability:  1.0
# Bigram: ('صبح', 'جگادیاکیجیئے')  Probability:  1.0
# Bigram: ('جگادیاکیجیئے', 'وہ')  Probability:  1.0
# Bigram: ('وہ', 'حضرت')  Probability:  1.0
# Bigram: ('حضرت', 'بھی')  Probability:  1.0
# Bigram: ('بھی', 'معلوم')  Probability:  0.19999999999999998
# Bigram: ('معلوم', 'ہوتاہےلفظوںکے')  Probability:  0.5
# Bigram: ('ہوتاہےلفظوںکے', 'بھوکے')  Probability:  1.0
# Bigram: ('بھوکے', 'بیٹھے')  Probability:  1.0
# Bigram: ('بیٹھے', 'تھے')  Probability:  0.5
# Bigram: ('تھے', 'دوسرے')  Probability:  0.3333333333333333
# Bigram: ('دوسرے', 'دن')  Probability:  0.5
# Bigram: ('دن', 'اٹھتے')  Probability:  0.25
# Bigram: ('اٹھتے', 'ہی')  Probability:  1.0
# Bigram: ('ہی', 'انھوںنے')  Probability:  0.25
# Bigram: ('انھوںنے', 'ایشورکا')  Probability:  1.0
# Bigram: ('ایشورکا', 'نام')  Probability:  1.0
# Bigram: ('نام', 'لے')  Probability:  1.0
# Bigram: ('لے', 'کرہما')  Probability:  1.0
# Bigram: ('کرہما', 'سینما')  Probability:  1.0
# Bigram: ('سینما', 'کا')  Probability:  1.0
# Bigram: ('کا', 'عشق')  Probability:  0.14285714285714288
# Bigram: ('عشق', 'عنوان')  Probability:  1.0
# Bigram: ('عنوان', 'تو')  Probability:  1.0
# Bigram: ('تو', 'عجب')  Probability:  0.19999999999999998
# Bigram: ('عجب', 'ہوس')  Probability:  1.0
# Bigram: ('ہوس', 'خیزہے')  Probability:  1.0
# Bigram: ('خیزہے', 'لیکن')  Probability:  1.0
# Bigram: ('لیکن', 'افسوس')  Probability:  0.25
# Bigram: ('افسوس', 'کہ')  Probability:  1.0
# Bigram: ('اس', 'مضمون')  Probability:  0.2222222222222222
# Bigram: ('مضمون', 'سے')  Probability:  0.3333333333333333
# Bigram: ('سے', 'آپ')  Probability:  0.2222222222222222
# Bigram: ('آپ', 'کی')  Probability:  0.19999999999999998
# Bigram: ('کی', 'تمام')  Probability:  0.125
# Bigram: ('تمام', 'توقعات')  Probability:  1.0
# Bigram: ('توقعات', 'مجروح')  Probability:  1.0
# Bigram: ('مجروح', 'ہوںگی')  Probability:  1.0
# Bigram: ('ہوںگی', 'کیونکہ')  Probability:  1.0
# Bigram: ('کیونکہ', 'مجھے')  Probability:  1.0
# Bigram: ('مجھے', 'تو')  Probability:  0.5
# Bigram: ('تو', 'اس')  Probability:  0.19999999999999998
# Bigram: ('مضمون', 'میں')  Probability:  0.3333333333333333
# Bigram: ('میں', 'کچھ')  Probability:  0.05555555555555555
# Bigram: ('کچھ', 'دل')  Probability:  1.0
# Bigram: ('دل', 'کے')  Probability:  1.0
# Bigram: ('کے', 'داغ')  Probability:  0.07142857142857144
# Bigram: ('داغ', 'دکھانے')  Probability:  1.0
# Bigram: ('دکھانے', 'مقصود')  Probability:  1.0
# Bigram: ('مقصود', 'ہیں')  Probability:  1.0
# Bigram: ('ہیں', 'اس')  Probability:  0.5
# Bigram: ('اس', 'سے')  Probability:  0.1111111111111111
# Bigram: ('آپ', 'یہ')  Probability:  0.19999999999999998
# Bigram: ('یہ', 'نہ')  Probability:  0.25
# Bigram: ('نہ', 'سمجھئے')  Probability:  0.5
# Bigram: ('سمجھئے', 'کہ')  Probability:  1.0
# Bigram: ('کہ', 'مجھے')  Probability:  0.1111111111111111
# Bigram: ('مجھے', 'فلموں')  Probability:  0.5
# Bigram: ('فلموں', 'سے')  Probability:  1.0
# Bigram: ('سے', 'دلچسپی')  Probability:  0.1111111111111111
# Bigram: ('دلچسپی', 'نہیں')  Probability:  1.0
# Bigram: ('نہیں', 'یا')  Probability:  0.25
# Bigram: ('یا', 'سینماکی')  Probability:  1.0
# Bigram: ('سینماکی', 'موسیقی')  Probability:  1.0
# Bigram: ('موسیقی', 'اورتاریکی')  Probability:  0.5
# Bigram: ('اورتاریکی', 'میں')  Probability:  1.0
# Bigram: ('میں', 'جوارمان')  Probability:  0.05555555555555555
# Bigram: ('جوارمان', 'انگیز')  Probability:  1.0
# Bigram: ('انگیز', 'یہے')  Probability:  1.0
# Bigram: ('یہے', 'میں')  Probability:  1.0
# Bigram: ('میں', 'اس')  Probability:  0.05555555555555555
# Bigram: ('اس', 'کا')  Probability:  0.1111111111111111
# Bigram: ('کا', 'قائل')  Probability:  0.14285714285714288
# Bigram: ('قائل', 'نہیں')  Probability:  1.0
# Bigram: ('نہیں', 'میں')  Probability:  0.25
# Bigram: ('میں', 'تو')  Probability:  0.05555555555555555
# Bigram: ('تو', 'سینماکے')  Probability:  0.19999999999999998
# Bigram: ('سینماکے', 'معاملے')  Probability:  1.0
# Bigram: ('معاملے', 'میں')  Probability:  1.0
# Bigram: ('میں', 'اوائل')  Probability:  0.05555555555555555
# Bigram: ('اوائل', 'عمر')  Probability:  1.0
# Bigram: ('عمر', 'ہی')  Probability:  1.0
# Bigram: ('ہی', 'سے')  Probability:  0.25
# Bigram: ('سے', 'بزرگ')  Probability:  0.1111111111111111
# Bigram: ('بزرگ', 'تمہید')  Probability:  1.0
# Bigram: ('تمہید', 'تمہید')  Probability:  0.5
# Bigram: ('تمہید', 'کے')  Probability:  0.5
# Bigram: ('کے', 'طور')  Probability:  0.07142857142857144
# Bigram: ('پر', 'صرف')  Probability:  0.25
# Bigram: ('صرف', 'اتنا')  Probability:  0.5
# Bigram: ('اتنا', 'عرض')  Probability:  1.0
# Bigram: ('عرض', 'کرنا')  Probability:  0.5
# Bigram: ('کرنا', 'چاہتا')  Probability:  1.0
# Bigram: ('چاہتا', 'ہوں')  Probability:  1.0
# Bigram: ('کہ', 'لاہور')  Probability:  0.1111111111111111
# Bigram: ('لاہور', 'کو')  Probability:  0.5
# Bigram: ('کو', 'دریافت')  Probability:  0.19999999999999998
# Bigram: ('دریافت', 'ہوئے')  Probability:  1.0
# Bigram: ('ہوئے', 'اب')  Probability:  0.5
# Bigram: ('اب', 'بہت')  Probability:  0.5
# Bigram: ('بہت', 'عرصہ')  Probability:  1.0
# Bigram: ('عرصہ', 'گزر')  Probability:  1.0
# Bigram: ('گزر', 'چکا')  Probability:  1.0
# Bigram: ('چکا', 'ہے')  Probability:  1.0
# Bigram: ('ہے', 'اس')  Probability:  0.19999999999999998
# Bigram: ('اس', 'لیے')  Probability:  0.1111111111111111
# Bigram: ('لیے', 'دلائل')  Probability:  0.5
# Bigram: ('دلائل', 'وبراہین')  Probability:  1.0
# Bigram: ('وبراہین', 'سے')  Probability:  1.0
# Bigram: ('سے', 'اس')  Probability:  0.1111111111111111
# Bigram: ('کے', 'وجود')  Probability:  0.07142857142857144
# Bigram: ('وجود', 'کو')  Probability:  1.0
# Bigram: ('کو', 'ثابت')  Probability:  0.19999999999999998
# Bigram: ('ثابت', 'کرنے')  Probability:  1.0
# Bigram: ('کرنے', 'کی')  Probability:  1.0
# Bigram: ('کی', 'ضرورت')  Probability:  0.125
# Bigram: ('ضرورت', 'نہیں')  Probability:  1.0
# Bigram: ('نہیں', 'یہ')  Probability:  0.25
# Bigram: ('یہ', 'کہنے')  Probability:  0.25
# Bigram: ('کہنے', 'کی')  Probability:  1.0
# Bigram: ('کی', 'اب')  Probability:  0.125
# Bigram: ('اب', 'ضرورت')  Probability:  0.5
# Bigram: ('نہیں', 'کہ')  Probability:  0.25
# Bigram: ('کہ', 'کرے')  Probability:  0.1111111111111111
# Bigram: ('کرے', 'کو')  Probability:  0.5
# Bigram: ('کو', 'دائیں')  Probability:  0.19999999999999998
# Bigram: ('دائیں', 'سے')  Probability:  1.0
# Bigram: ('سے', 'بائیں')  Probability:  0.1111111111111111
# Bigram: ('بائیں', 'گھمائیے')  Probability:  1.0
# Bigram: ('گھمائیے', 'حتی')  Probability:  1.0
# Bigram: ('حتی', 'کہ')  Probability:  1.0
# Bigram: ('کہ', 'ہندوستان')  Probability:  0.1111111111111111
# Bigram: ('ہندوستان', 'کا')  Probability:  1.0
# Bigram: ('کا', 'ملک')  Probability:  0.14285714285714288
# Bigram: ('ملک', 'آپ')  Probability:  1.0
# Bigram: ('آپ', 'کے')  Probability:  0.19999999999999998
# Bigram: ('کے', 'سامنے')  Probability:  0.07142857142857144
# Bigram: ('سامنے', 'آکر')  Probability:  1.0
# Bigram: ('آکر', 'ٹھہر')  Probability:  1.0
# Bigram: ('ٹھہر', 'جائے')  Probability:  1.0
# Bigram: ('جائے', 'پھر')  Probability:  1.0
# Bigram: ('پھر', 'فلاں')  Probability:  1.0
# Bigram: ('فلاں', 'طول')  Probability:  0.5
# Bigram: ('طول', 'البلد')  Probability:  1.0
# Bigram: ('البلد', 'اور')  Probability:  0.5
# Bigram: ('اور', 'فلاں')  Probability:  0.14285714285714288
# Bigram: ('فلاں', 'عرض')  Probability:  0.5
# Bigram: ('عرض', 'البلد')  Probability:  0.5
# Bigram: ('البلد', 'کے')  Probability:  0.5
# Bigram: ('کے', 'مقام')  Probability:  0.07142857142857144
# Bigram: ('مقام', 'انقطاع')  Probability:  1.0
# Bigram: ('انقطاع', 'پر')  Probability:  1.0
# Bigram: ('پر', 'لاہ')  Probability:  0.25

# %% [markdown]
# ## Generating Text using the Shannon Visualization Method
#
# Generate a paragraph with ten sentences. Use the Shannon visualization method that we studied in class.

# %%
# code here
import random
possible_first_words = [word[0] for word in probabilties_bigrams]
sentences=[]
for j in range(10):
    print("Sentence number", j+1,":")

    #choosing the first word
    first_word=random.choice(possible_first_words)
    sentence=[]
    possible_words=[]
    # creating sentences of variable length - 8 to 15 words
    random_sentence_length = random.randint(8, 15)
    for i in range(random_sentence_length):
        current_word=first_word
        
        for word in probabilties_bigrams:
            if word[0==current_word]:
                possible_words.append(word[1] )
        
        next_word = random.choice(possible_words)
        sentence.append(next_word)
        current_word=next_word

    print(sentence)
    sentences.append(sentence)
# Out:
# Sentence number 1 :
# ['انقطاع', 'اے', 'کا', 'طرف', 'کے', 'تمہید', 'بعد', 'داستان']
# Sentence number 2 :
# ['کرے', 'صرف', 'کاشوق', 'دل', 'سے', 'کیونکہ', 'جو', 'بیٹھے', 'فوقتا', 'کرے', 'سوال', 'باتوں']
# Sentence number 3 :
# ['دونوں', 'تعلیم', 'لالہ', 'اور', 'کہ', 'چاہتا', 'تھے', 'کے', 'خبر', 'سمجھئے', 'لاہ', 'آتے', 'موسیقی']
# Sentence number 4 :
# ['نہ', 'کہ', 'یا', 'وجود', 'معاملے', 'ٹھہر', 'سامنے', 'تھےاس', 'نکرجی', 'ناہل', 'ہیڈ']
# Sentence number 5 :
# ['عرض', 'ا', 'عرض', 'عرصہ', 'انٹرنس', 'گی', 'ایک', 'طور', 'مدت', 'پھر', 'جوشامت', 'خاص', 'تو']
# Sentence number 6 :
# ['ٹھہر', 'ایک', 'ملک', 'عرض', 'کو', 'بائیں', 'میں', 'جگادیاکیجیئے', 'کے', 'کے']
# Sentence number 7 :
# ['طور', 'کے', 'بہت', 'انقطاع', 'موت', 'کی', 'اور', 'ہی', 'ہو']
# Sentence number 8 :
# ['سے', 'کیا', 'ہیںآپس', 'میرے', 'قریب', 'دائیں', 'کراچی', 'دریافت', 'عنوان']
# Sentence number 9 :
# ['خبر', 'میرے', 'کہ', 'آتیہےتوشہر', 'مدت', 'گزر', 'تھی', 'دکھانے', 'پر', 'دونوں', 'آپ']
# Sentence number 10 :
# ['البلد', 'جب', 'ادب', 'تمام', 'بائیں', 'اس', 'صبح', 'کی', 'تو', 'کی', 'لیکن']

# %% [markdown]
# ## Computing the Probability of Sentences
#
# Compute the probability of each sentence that has been generated in the previous step. Refer to the lecture slides to see what does it mean to compute the _probability of a sentence_.
#
# Apply the **unigram assumption** while computing these probabilities.

# %%
#code here 
# Unigram assumption so need to check individual probabilities of the tokens and multiply them together

for sentence in sentences:
    sentence_prob=1
    for word in sentence:
        individual_probability=probabilties[word]
        sentence_prob=sentence_prob*individual_probability
    
    print('Probability:', sentence_prob, "for sentence:",sentence)
# Out:
# Probability: 5.006100948636449e-19 for sentence: ['انقطاع', 'اے', 'کا', 'طرف', 'کے', 'تمہید', 'بعد', 'داستان']
# Probability: 1.314355333120921e-29 for sentence: ['کرے', 'صرف', 'کاشوق', 'دل', 'سے', 'کیونکہ', 'جو', 'بیٹھے', 'فوقتا', 'کرے', 'سوال', 'باتوں']
# Probability: 1.1809916501758885e-30 for sentence: ['دونوں', 'تعلیم', 'لالہ', 'اور', 'کہ', 'چاہتا', 'تھے', 'کے', 'خبر', 'سمجھئے', 'لاہ', 'آتے', 'موسیقی']
# Probability: 3.359820820290354e-28 for sentence: ['نہ', 'کہ', 'یا', 'وجود', 'معاملے', 'ٹھہر', 'سامنے', 'تھےاس', 'نکرجی', 'ناہل', 'ہیڈ']
# Probability: 3.347482001632337e-32 for sentence: ['عرض', 'ا', 'عرض', 'عرصہ', 'انٹرنس', 'گی', 'ایک', 'طور', 'مدت', 'پھر', 'جوشامت', 'خاص', 'تو']
# Probability: 1.3466833811887797e-21 for sentence: ['ٹھہر', 'ایک', 'ملک', 'عرض', 'کو', 'بائیں', 'میں', 'جگادیاکیجیئے', 'کے', 'کے']
# Probability: 5.875130697666248e-20 for sentence: ['طور', 'کے', 'بہت', 'انقطاع', 'موت', 'کی', 'اور', 'ہی', 'ہو']
# Probability: 5.620341866389907e-23 for sentence: ['سے', 'کیا', 'ہیںآپس', 'میرے', 'قریب', 'دائیں', 'کراچی', 'دریافت', 'عنوان']
# Probability: 3.359820820290354e-27 for sentence: ['خبر', 'میرے', 'کہ', 'آتیہےتوشہر', 'مدت', 'گزر', 'تھی', 'دکھانے', 'پر', 'دونوں', 'آپ']
# Probability: 4.300570649971653e-25 for sentence: ['البلد', 'جب', 'ادب', 'تمام', 'بائیں', 'اس', 'صبح', 'کی', 'تو', 'کی', 'لیکن']

# %% [markdown]
# ## Discussion and Evaluation
#
# - Analyze the text generated, and mention 3 distinct observations. Also compare it with the input text and how different it is and why might that be.
#
# - Do you notice any repetition of words in the generated sentences? If yes, how would you solve it?
#
# - Is going upto `n=2` enough? What do you think would be a good value of n and why?
#
#
# Answer here:
# <div style="color:green;">
# ...
#
# - Three obsrvations:
#
# 1. The quality of the text generated and the words doesn't seem to be very good. This might be due to generation method issues.
# 2. The sentences generated are alot less coherent than the ones in the inputs.
# 3. The sentences generated are of variable lengths due to randomness given however in the inputs, the sentence stucture as well as the sentence length is depenedant on the meaning and contextual linkage.
#
# - Repitition:
# There is a definite repitition in words in the generated sentences like (the urdu word aur) becuase of the repition of the word in the input sentences as well. This makes sense as higher probable words are going to repeat more often as we are using bigrams so certain words have a higher probability of following others.
# We can solve this by trying other methods like trigrams or higher order grams. We can also maybe limit the number of times a word appears in generation to put a bias towards less repeating words.
#
# - N-gram level:
# The quality of text generated shows that n=2 is not enough as it doesnot capture any long term dependancy or variable sentence structures. Higher values of n can be tried and then the best can be figured out. It is hard to conclude that what value of n would be a good choice however it must be greater than 2 so that it can capture better sentence context and result in better generation (more human like). Input dataset will always pose a huge impact however.
# </div>
